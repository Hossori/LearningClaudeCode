# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"
system_prompt = """
あなたはとても簡潔にソリューションを提示できる優秀なエンジニアです。
"""

# %%
# Claude メッセージヘルパー
def to_user_message(text):
    user_message = {"role": "user", "content": text}
    return user_message

def to_assistant_message(text):
    assistant_message = {"role": "assistant", "content": text}
    return assistant_message

def chat(messages, temperature=0.0):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        temperature = temperature,
        messages = messages,
        system = system_prompt
    )
    return message.content[0].text

# %%
messages = []
while(True):
    inputMessage = input("> ")
    if inputMessage == '':
        print('no text input, terminate this program.')
        break

    print(">", inputMessage)
    user_message = to_user_message(inputMessage)
    messages.append(user_message)

    print('---------')
    outputMessage = chat(messages)
    print(outputMessage)
    print('---------')
    assistant_message = to_assistant_message(outputMessage)
    messages.append(assistant_message)
# Out:
# > 映画のアイディアを出して
# ---
# # 映画のアイディア5選
#
# ## 1. **「記憶の置き手紙」**
# 認知症の父が毎日、娘を初対面のように迎える。娘は父の「その日限りの人生」を一緒に生きることで、家族の本当の繋がりを見つける。
#
# ## 2. **「デジタル幽霊」**
# SNS依存の若者が、急死した友人のAIチャットボットと会話を続ける。次第に、それが本当に友人なのかAIなのか、区別がつかなくなっていく心理サスペンス。
#
# ## 3. **「夜間警備員の事件簿」**
# 無名なビルの夜間警備員が、ビル内で起きる不可解な出来事を目撃。監視カメラだけが真実を知っている。
#
# ## 4. **「二番目の人生」**
# 定年退職した元サラリーマンが、昔の夢だった音楽活動を始める。人生後半戦で本気を出す男たちの青春群像劇。
#
# ## 5. **「消えた24時間」**
# 目を覚ますと丸1日の記憶がない。その間に何が起きたのか、自分の行動を追う。ミステリー × 自分探し。
#
# ---
#
# どのジャンル・テーマに興味ありますか？
# ---
# no text input, terminate this program.
